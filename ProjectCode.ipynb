# %% [markdown]
# Github sharing code
# - 3 buttons in source control --> pull
# - push -->
# save
# hover over changes click + on notebook

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train_data.csv")
df.head()
# Out:
#    Index  Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0      0          0                                           0.450397
# 1      1          0                                           0.530005
# 2      2          0                                           0.571150
# 3      3          0                                           0.483401
# 4      4          0                                           0.510359
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.504034
# 1                                 0.572885
# 2                                 0.620148
# 3                                 0.556694
# 4                                 0.537287
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.506986
# 1                                           0.574763
# 2                                           0.624177
# ...

# %%
df.shape
# Out:
# (5807, 97)

# %%
unique = pd.unique(df['Bankrupt?'])
unique
# Out:
# array([0, 1], dtype=int64)
