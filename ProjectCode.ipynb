# %% [markdown]
# Github sharing code
# - 3 buttons in source control --> pull
# - push -->
# save
# hover over changes click + on notebook
# push & commit

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("train_data.csv")
df.head()
print(df.shape)
print(df.columns)
# Out:
# (5807, 97)
# Index(['Index', 'Bankrupt?',
#        ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
#        ' Realized Sales Gross Profit Growth Rate',
#        ' Operating Profit Growth Rate', ' After-tax Net Profit Growth Rate',
#        ' Regular Net Profit Growth Rate', ' Continuous Net Profit Growth Rate',
#        ' Total Asset Growth Rate', ' Net Value Growth Rate',
#        ' Total Asset Return Growth Rate Ratio', ' Cash Reinvestment %',
#        ' Current Ratio', ' Quick Ratio', ' Interest Expense Ratio',
#        ' Total debt/Total net worth', ' Debt ratio %', ' Net worth/Assets',
#        ' Long-term fund suitability ratio (A)', ' Borrowing dependency',
#        ' Contingent liabilities/Net worth',
#        ' Operating profit/Paid-in capital',
#        ' Net profit before tax/Paid-in capital',
#        ' Inventory and accounts receivable/Net value', ' Total Asset Turnover',
#        ' Accounts Receivable Turnover', ' Average Collection Days',
#        ' Inventory Turnover Rate (times)', ' Fixed Assets Turnover Frequency',
#        ' Net Worth Turnover Rate (times)', ' Revenue per person',
#        ' Operating profit per person', ' Allocation rate per person',
#        ' Working Capital to Total Assets', ' Quick Assets/Total Assets',
#        ' Current Assets/Total Assets', ' Cash/Total Assets',
#        ' Quick Assets/Current Liability', ' Cash/Current Liability',
#        ' Current Liability to Assets', ' Operating Funds to Liability',
#        ' Inventory/Working Capital', ' Inventory/Current Liability',
#        ' Current Liabilities/Liability', ' Working Capital/Equity',
#        ' Current Liabilities/Equity', ' Long-term Liability to Current Assets',
#        ' Retained Earnings to Total Assets', ' Total income/Total expense',
#        ' Total expense/Assets', ' Current Asset Turnover Rate',
#        ' Quick Asset Turnover Rate', ' Working capitcal Turnover Rate',
#        ' Cash Turnover Rate', ' Cash Flow to Sales', ' Fixed Assets to Assets',
#        ' Current Liability to Liability', ' Current Liability to Equity',
#        ' Equity to Long-term Liability', ' Cash Flow to Total Assets',
#        ' Cash Flow to Liability', ' CFO to Assets', ' Cash Flow to Equity',
#        ' Current Liability to Current Assets', ' Liability-Assets Flag',
#        ' Net Income to Total Assets', ' Total assets to GNP price',
#        ' No-credit Interval', ' Gross Profit to Sales',
#        ' Net Income to Stockholder's Equity', ' Liability to Equity',
#        ' Degree of Financial Leverage (DFL)',
#        ' Interest Coverage Ratio (Interest expense to EBIT)',
#        ' Net Income Flag', ' Equity to Liability'],
#       dtype='object')

# %%
# Check for null values and count them in each column
null_counts = df.isnull().sum()

# Print the count of null values for columns that have more than one null value
for column, count in null_counts.items():
    if count > 1:
        print(f"{column}: {count}")

# %% [markdown]
# There are no null values in our data

# %%
# Pearson Correlation calculations
list_to_drop = []
target = 'Bankrupt?'
print("\nPearson Correlations:")
for column in df.columns:
    if column != target:  # Avoid calculating correlation of the variable with itself
        if df[column].isnull().sum() == 0:  # Ensuring no NaN values which would cause errors
            pearson_corr = df['Bankrupt?'].corr(df[column])
            print(f'Pearson Correlation between {target} and {column}: {pearson_corr:.2f}')
            if abs(pearson_corr) < 0.07:  # Use a small threshold rather than exactly 0.00
                list_to_drop.append(column)
        else:
            print(f'Cannot calculate correlation for {column} due to null values')
# Out:
# Pearson Correlations:
# Pearson Correlation between Bankrupt? and Index: 0.00
# Pearson Correlation between Bankrupt? and  ROA(C) before interest and depreciation before interest: -0.26
# Pearson Correlation between Bankrupt? and  ROA(A) before interest and % after tax: -0.28
# Pearson Correlation between Bankrupt? and  ROA(B) before interest and depreciation after tax: -0.27
# Pearson Correlation between Bankrupt? and  Operating Gross Margin: -0.10
# Pearson Correlation between Bankrupt? and  Realized Sales Gross Margin: -0.10
# Pearson Correlation between Bankrupt? and  Operating Profit Rate: 0.00
# Pearson Correlation between Bankrupt? and  Pre-tax net Interest Rate: -0.01
# Pearson Correlation between Bankrupt? and  After-tax net Interest Rate: -0.01
# Pearson Correlation between Bankrupt? and  Non-industry income and expenditure/revenue: -0.02
# Pearson Correlation between Bankrupt? and  Continuous interest rate (after tax): -0.01
# Pearson Correlation between Bankrupt? and  Operating Expense Rate: -0.00
# Pearson Correlation between Bankrupt? and  Research and development expense rate: -0.03
# Pearson Correlation between Bankrupt? and  Cash flow rate: -0.08
# Pearson Correlation between Bankrupt? and  Interest-bearing debt interest rate: -0.02
# Pearson Correlation between Bankrupt? and  Tax rate (A): -0.11
# Pearson Correlation between Bankrupt? and  Net Value Per Share (B): -0.16
# Pearson Correlation between Bankrupt? and  Net Value Per Share (A): -0.16
# Pearson Correlation between Bankrupt? and  Net Value Per Share (C): -0.16
# Pearson Correlation between Bankrupt? and  Persistent EPS in the Last Four Seasons: -0.21
# Pearson Correlation between Bankrupt? and  Cash Flow Per Share: -0.08
# Pearson Correlation between Bankrupt? and  Revenue Per Share (Yuan ¥): -0.00
# Pearson Correlation between Bankrupt? and  Operating Profit Per Share (Yuan ¥): -0.14
# Pearson Correlation between Bankrupt? and  Per Share Net profit before tax (Yuan ¥): -0.20
# Pearson Correlation between Bankrupt? and  Realized Sales Gross Profit Growth Rate: -0.00
# Pearson Correlation between Bankrupt? and  Operating Profit Growth Rate: -0.02
# Pearson Correlation between Bankrupt? and  After-tax Net Profit Growth Rate: -0.04
# Pearson Correlation between Bankrupt? and  Regular Net Profit Growth Rate: -0.04
# Pearson Correlation between Bankrupt? and  Continuous Net Profit Growth Rate: -0.01
# Pearson Correlation between Bankrupt? and  Total Asset Growth Rate: -0.04
# Pearson Correlation between Bankrupt? and  Net Value Growth Rate: 0.07
# Pearson Correlation between Bankrupt? and  Total Asset Return Growth Rate Ratio: -0.02
# Pearson Correlation between Bankrupt? and  Cash Reinvestment %: -0.09
# Pearson Correlation between Bankrupt? and  Current Ratio: -0.00
# Pearson Correlation between Bankrupt? and  Quick Ratio: 0.03
# Pearson Correlation between Bankrupt? and  Interest Expense Ratio: -0.00
# Pearson Correlation between Bankrupt? and  Total debt/Total net worth: 0.01
# Pearson Correlation between Bankrupt? and  Debt ratio %: 0.26
# Pearson Correlation between Bankrupt? and  Net worth/Assets: -0.26
# Pearson Correlation between Bankrupt? and  Long-term fund suitability ratio (A): 0.03
# Pearson Correlation between Bankrupt? and  Borrowing dependency: 0.19
# Pearson Correlation between Bankrupt? and  Contingent liabilities/Net worth: 0.07
# Pearson Correlation between Bankrupt? and  Operating profit/Paid-in capital: -0.14
# Pearson Correlation between Bankrupt? and  Net profit before tax/Paid-in capital: -0.20
# Pearson Correlation between Bankrupt? and  Inventory and accounts receivable/Net value: 0.09
# Pearson Correlation between Bankrupt? and  Total Asset Turnover: -0.07
# Pearson Correlation between Bankrupt? and  Accounts Receivable Turnover: -0.00
# Pearson Correlation between Bankrupt? and  Average Collection Days: -0.01
# Pearson Correlation between Bankrupt? and  Inventory Turnover Rate (times): 0.00
# Pearson Correlation between Bankrupt? and  Fixed Assets Turnover Frequency: 0.07
# Pearson Correlation between Bankrupt? and  Net Worth Turnover Rate (times): 0.02
# Pearson Correlation between Bankrupt? and  Revenue per person: 0.07
# Pearson Correlation between Bankrupt? and  Operating profit per person: -0.09
# Pearson Correlation between Bankrupt? and  Allocation rate per person: 0.00
# Pearson Correlation between Bankrupt? and  Working Capital to Total Assets: -0.20
# Pearson Correlation between Bankrupt? and  Quick Assets/Total Assets: -0.08
# Pearson Correlation between Bankrupt? and  Current Assets/Total Assets: -0.05
# Pearson Correlation between Bankrupt? and  Cash/Total Assets: -0.10
# Pearson Correlation between Bankrupt? and  Quick Assets/Current Liability: -0.00
# Pearson Correlation between Bankrupt? and  Cash/Current Liability: 0.08
# Pearson Correlation between Bankrupt? and  Current Liability to Assets: 0.20
# Pearson Correlation between Bankrupt? and  Operating Funds to Liability: -0.08
# Pearson Correlation between Bankrupt? and  Inventory/Working Capital: -0.00
# Pearson Correlation between Bankrupt? and  Inventory/Current Liability: 0.00
# Pearson Correlation between Bankrupt? and  Current Liabilities/Liability: -0.03
# Pearson Correlation between Bankrupt? and  Working Capital/Equity: -0.15
# Pearson Correlation between Bankrupt? and  Current Liabilities/Equity: 0.16
# Pearson Correlation between Bankrupt? and  Long-term Liability to Current Assets: -0.01
# Pearson Correlation between Bankrupt? and  Retained Earnings to Total Assets: -0.25
# Pearson Correlation between Bankrupt? and  Total income/Total expense: -0.01
# Pearson Correlation between Bankrupt? and  Total expense/Assets: 0.15
# Pearson Correlation between Bankrupt? and  Current Asset Turnover Rate: 0.01
# Pearson Correlation between Bankrupt? and  Quick Asset Turnover Rate: 0.02
# Pearson Correlation between Bankrupt? and  Working capitcal Turnover Rate: -0.00
# Pearson Correlation between Bankrupt? and  Cash Turnover Rate: -0.02
# Pearson Correlation between Bankrupt? and  Cash Flow to Sales: 0.00
# Pearson Correlation between Bankrupt? and  Fixed Assets to Assets: 0.07
# Pearson Correlation between Bankrupt? and  Current Liability to Liability: -0.03
# Pearson Correlation between Bankrupt? and  Current Liability to Equity: 0.16
# Pearson Correlation between Bankrupt? and  Equity to Long-term Liability: 0.17
# Pearson Correlation between Bankrupt? and  Cash Flow to Total Assets: -0.08
# Pearson Correlation between Bankrupt? and  Cash Flow to Liability: -0.05
# Pearson Correlation between Bankrupt? and  CFO to Assets: -0.12
# Pearson Correlation between Bankrupt? and  Cash Flow to Equity: -0.06
# Pearson Correlation between Bankrupt? and  Current Liability to Current Assets: 0.16
# Pearson Correlation between Bankrupt? and  Liability-Assets Flag: 0.13
# Pearson Correlation between Bankrupt? and  Net Income to Total Assets: -0.32
# Pearson Correlation between Bankrupt? and  Total assets to GNP price: 0.02
# Pearson Correlation between Bankrupt? and  No-credit Interval: -0.01
# Pearson Correlation between Bankrupt? and  Gross Profit to Sales: -0.10
# Pearson Correlation between Bankrupt? and  Net Income to Stockholder's Equity: -0.18
# Pearson Correlation between Bankrupt? and  Liability to Equity: 0.18
# Pearson Correlation between Bankrupt? and  Degree of Financial Leverage (DFL): 0.02
# Pearson Correlation between Bankrupt? and  Interest Coverage Ratio (Interest expense to EBIT): -0.00
# Pearson Correlation between Bankrupt? and  Net Income Flag: nan
# Pearson Correlation between Bankrupt? and  Equity to Liability: -0.09
# C:\Users\edwar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\edwar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# Interpreting the Correlation Values (Pearson correlation)
#
# Close to +1: Strong positive relationship.
#
# Close to -1: Strong negative relationship.
#
# Close to 0: No linear relationship.
#
# Intermediate values: Indicates the degree of linear relationship between variables.
#
# Drop columns that are close to 0 with a threshold of -0.07<x<0.07

# %%
t = df[' Net Income Flag']
unique = pd.unique(t)
unique
# Out:
# array([1], dtype=int64)

# %%
list_to_drop.append(' Net Income Flag')
list_to_drop
# Out:
# ['Index',
#  ' Operating Profit Rate',
#  ' Pre-tax net Interest Rate',
#  ' After-tax net Interest Rate',
#  ' Non-industry income and expenditure/revenue',
#  ' Continuous interest rate (after tax)',
#  ' Operating Expense Rate',
#  ' Research and development expense rate',
#  ' Interest-bearing debt interest rate',
#  ' Revenue Per Share (Yuan ¥)',
#  ' Realized Sales Gross Profit Growth Rate',
#  ' Operating Profit Growth Rate',
#  ' After-tax Net Profit Growth Rate',
#  ' Regular Net Profit Growth Rate',
#  ' Continuous Net Profit Growth Rate',
#  ' Total Asset Growth Rate',
#  ' Net Value Growth Rate',
#  ' Total Asset Return Growth Rate Ratio',
#  ' Current Ratio',
#  ' Quick Ratio',
#  ' Interest Expense Ratio',
#  ' Total debt/Total net worth',
#  ' Long-term fund suitability ratio (A)',
#  ' Total Asset Turnover',
#  ' Accounts Receivable Turnover',
#  ' Average Collection Days',
#  ' Inventory Turnover Rate (times)',
#  ' Net Worth Turnover Rate (times)',
#  ' Revenue per person',
#  ' Allocation rate per person',
#  ' Current Assets/Total Assets',
#  ' Quick Assets/Current Liability',
#  ' Inventory/Working Capital',
#  ' Inventory/Current Liability',
#  ' Current Liabilities/Liability',
#  ' Long-term Liability to Current Assets',
#  ' Total income/Total expense',
#  ' Current Asset Turnover Rate',
#  ' Quick Asset Turnover Rate',
#  ' Working capitcal Turnover Rate',
#  ' Cash Turnover Rate',
#  ' Cash Flow to Sales',
#  ' Fixed Assets to Assets',
#  ' Current Liability to Liability',
#  ' Cash Flow to Liability',
#  ' Cash Flow to Equity',
#  ' Total assets to GNP price',
#  ' No-credit Interval',
#  ' Degree of Financial Leverage (DFL)',
#  ' Interest Coverage Ratio (Interest expense to EBIT)',
#  ' Net Income Flag']

# %%
df = df.drop(columns= list_to_drop)
df.shape
# Out:
# (5807, 46)

# %%
# Assuming 'df' is your DataFrame.

# Loop through each column in the DataFrame
for column in df.columns:
    # Check if the column is numeric
    if pd.api.types.is_numeric_dtype(df[column]):
        
        x = 1
        # Histogram -- commenting out for now
        #plt.figure(figsize=(10, 4))
        #plt.hist(df[column], bins=30, alpha=0.7, color='blue', density=True)
        #plt.title(f'Histogram of {column}')
        #plt.show() 

        # Q-Q plot -- commenting out for now
        #fig, ax = plt.subplots(figsize=(10, 4))
        #stats.probplot(df[column], dist="norm", plot=ax)
        #ax.set_title(f'Q-Q plot of {column}')
        #plt.show() 
    else:
        print(f"Skipped {column}: Not a numeric data type.")

# %% [markdown]
# PART 2

# %%
train_X = df.drop(['Bankrupt?'], axis=1)
train_Y = df['Bankrupt?']

inertias = []
for i in range(1, 10):
    kmeans = KMeans(i)
    kmeans.fit(train_X)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,10),inertias)
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %% [markdown]
# Best cluster is probably 2 but since we have 4 group members we will go with 4

# %%
pca = PCA(3).fit_transform(df)
kmeans = KMeans(4)
labels = kmeans.fit_predict(pca)
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(pca[:, 0], pca[:, 1], pca[:, 2], c=labels, cmap='viridis',edgecolor='k')
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], c='red', s=300, marker='X')
plt.show()

# %%
pca = PCA(2).fit_transform(df)
kmeans = KMeans(4)
labels = kmeans.fit_predict(pca)
plt.scatter(pca[:, 0], pca[:, 1], c=labels, cmap='viridis', edgecolor='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', s=300, marker='X')
plt.show()

# %% [markdown]
# The desity of all but one of the clusters is high meaning the varriance within the other 3 is small, and there around 2-10 outliers per cluster. There also seems to be some overlap within clusters which could mean similarites between subgroups.
